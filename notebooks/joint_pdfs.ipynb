# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
import sys
sys.path.insert(0,"../python")

# %%
from load_sim_tigresspp import LoadSimTIGRESSPP

# %%
sim = LoadSimTIGRESSPP("/scratch/gpfs/EOST/changgoo/tigress_classic/crmhd-8pc-b1-mhdbc_diode-crbc_lngrad_out-sigma28_va1/",verbose=True)
# Out:
# [LoadSimTIGRESSPP-INFO] basedir: /scratch/gpfs/EOST/changgoo/tigress_classic/crmhd-8pc-b1-mhdbc_diode-crbc_lngrad_out-sigma28_va1
# [LoadSimTIGRESSPP-INFO] savdir: /scratch/gpfs/EOST/changgoo/tigress_classic/crmhd-8pc-b1-mhdbc_diode-crbc_lngrad_out-sigma28_va1
# [LoadSimTIGRESSPP-INFO] load_method: xarray
# [FindFiles-INFO] athinput: /scratch/gpfs/EOST/changgoo/tigress_classic/crmhd-8pc-b1-mhdbc_diode-crbc_lngrad_out-sigma28_va1/athinput.runtime
# [FindFiles-INFO] athena_variant: Athena++
# [FindFiles-INFO] problem_id: TIGRESS
# [FindFiles-INFO] hdf5 (prim,uov): /scratch/gpfs/EOST/changgoo/tigress_classic/crmhd-8pc-b1-mhdbc_diode-crbc_lngrad_out-sigma28_va1 nums: 0-383
# [FindFiles-WARNING] hdf5 (d,p,Ec) files not found in /scratch/gpfs/EOST/changgoo/tigress_classic/crmhd-8pc-b1-mhdbc_diode-crbc_lngrad_out-sigma28_va1
# [FindFiles-INFO] parbin (par0): /scratch/gpfs/EOST/changgoo/tigress_classic/crmhd-8pc-b1-mhdbc_diode-crbc_lngrad_out-sigma28_va1 nums: 0-383
# [FindFiles-INFO] parhst: /scratch/gpfs/EOST/changgoo/tigress_classic/crmhd-8pc-b1-mhdbc_diode-crbc_lngrad_out-sigma28_va1 pids: 1-406
# [FindFiles-INFO] loop_time: /scratch/gpfs/EOST/changgoo/tigress_classic/crmhd-8pc-b1-mhdbc_diode-crbc_lngrad_out-sigma28_va1/TIGRESS.loop_time.txt
# [FindFiles-INFO] task_time: /scratch/gpfs/EOST/changgoo/tigress_classic/crmhd-8pc-b1-mhdbc_diode-crbc_lngrad_out-sigma28_va1/TIGRESS.task_time.txt
# [FindFiles-INFO] hst: /scratch/gpfs/EOST/changgoo/tigress_classic/crmhd-8pc-b1-mhdbc_diode-crbc_lngrad_out-sigma28_va1/TIGRESS.hst
# [FindFiles-INFO] sn: /scratch/gpfs/EOST/changgoo/tigress_classic/crmhd-8pc-b1-mhdbc_diode-crbc_lngrad_out-sigma28_va1/TIGRESS.sn
# [FindFiles-INFO] zprof: /scratch/gpfs/EOST/changgoo/tigress_classic/crmhd-8pc-b1-mhdbc_diode-crbc_lngrad_out-sigma28_va1 nums: 0-383
# [FindFiles-INFO] rst: /scratch/gpfs/EOST/changgoo/tigress_classic/crmhd-8pc-b1-mhdbc_diode-crbc_lngrad_out-sigma28_va1 nums: 0-7 final: yes

# %%
# example getting one pdf
pdf = sim.get_windpdf(sim.nums[-1],"windpdf")
# Out:
# [LoadSimTIGRESSPP-INFO] [check_netcdf]: Read original dump.

# %%
# creating all wind pdfs
sim.create_windpdf()
# Out:
# [LoadSimTIGRESSPP-INFO] Merged wind pdfs are not found. Creating new wind pdfs...
# [LoadSimTIGRESSPP-INFO] [check_netcdf]: Read original dump.
# [LoadSimTIGRESSPP-INFO] [check_netcdf]: Read original dump.
# [LoadSimTIGRESSPP-INFO] [check_netcdf]: Read original dump.
